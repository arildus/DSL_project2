# %%
import numpy as np
import csv
import matplotlib.pyplot as plt
from operator import itemgetter
import cmath

# %%
file = open("development.csv", "r")
csvreader = csv.reader(file)

# %%
rows = []
for row in csvreader:
    rows.append(row)

# %%
TRAINING_DATA_with_header = np.asarray(rows)
TRAINING_DATA = TRAINING_DATA_with_header[1:TRAINING_DATA_with_header.size,:]

# %%
x = TRAINING_DATA[:, 0]
sensor_num = 6
y = TRAINING_DATA[:,1]
pmax = TRAINING_DATA[:, 2+5*sensor_num]
tmax = TRAINING_DATA[:, 4+5*sensor_num]

# %%
# data = [(float(x[i]), float(pmax[i])) for i in range(len(x))]

# %%
# sorted_by_x = sorted(data, key=itemgetter(1))

# %%
x = [float(x_i) for x_i in x]
y = [float(y_i) for y_i in y]
pmax = [float(pmax_i) for pmax_i in pmax]
tmax = [float(tmax_i) for tmax_i in tmax]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [392], line 1
# ----> 1 x = [float(x_i) for x_i in x]
#       2 y = [float(y_i) for y_i in y]
#       3 pmax = [float(pmax_i) for pmax_i in pmax]
#
# Cell In [392], line 1, in <listcomp>(.0)
# ----> 1 x = [float(x_i) for x_i in x]
#       2 y = [float(y_i) for y_i in y]
#       3 pmax = [float(pmax_i) for pmax_i in pmax]
#
# ValueError: could not convert string to float: 'x'

# %%
plt.scatter(x, y, c=pmax, cmap="viridis", s=2)
cbar = plt.colorbar()
cbar.set_label("Pmax")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axes/_axes.py:4220, in Axes._parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4219 try:  # Is 'c' acceptable as PathCollection facecolors?
# -> 4220     colors = mcolors.to_rgba_array(c)
#    4221 except (TypeError, ValueError) as err:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/colors.py:377, in to_rgba_array(c, alpha)
#     376 else:
# --> 377     rgba = np.array([to_rgba(cc) for cc in c])
#     379 if alpha is not None:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/colors.py:377, in <listcomp>(.0)
#     376 else:
# --> 377     rgba = np.array([to_rgba(cc) for cc in c])
#     379 if alpha is not None:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/colors.py:187, in to_rgba(c, alpha)
#     186 if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 187     rgba = _to_rgba_no_colorcycle(c, alpha)
#     188     try:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/colors.py:262, in _to_rgba_no_colorcycle(c, alpha)
#     261         return c, c, c, alpha if alpha is not None else 1.
# --> 262     raise ValueError(f"Invalid RGBA argument: {orig_c!r}")
#     263 # turn 2-D array into 1-D array
#
# ValueError: Invalid RGBA argument: 'pmax[6]'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In [388], line 1
# ----> 1 plt.scatter(x, y, c=pmax, cmap="viridis", s=2)
#       2 cbar = plt.colorbar()
#       3 cbar.set_label("Pmax")
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/pyplot.py:2817, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2812 @_copy_docstring_and_deprecators(Axes.scatter)
#    2813 def scatter(
#    2814         x, y, s=None, c=None, marker=None, cmap=None, norm=None,
#    2815         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2816         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2817     __ret = gca().scatter(
#    2818         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2819         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#    2820         edgecolors=edgecolors, plotnonfinite=plotnonfinite,
#    2821         **({"data": data} if data is not None else {}), **kwargs)
#    2822     sci(__ret)
#    2823     return __ret
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/__init__.py:1414, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1411 @functools.wraps(func)
#    1412 def inner(ax, *args, data=None, **kwargs):
#    1413     if data is None:
# -> 1414         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1416     bound = new_sig.bind(ax, *args, **kwargs)
#    1417     auto_label = (bound.arguments.get(label_namer)
#    1418                   or bound.kwargs.get(label_namer))
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axes/_axes.py:4386, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4383 if edgecolors is None:
#    4384     orig_edgecolor = kwargs.get('edgecolor', None)
#    4385 c, colors, edgecolors = \
# -> 4386     self._parse_scatter_color_args(
#    4387         c, edgecolors, kwargs, x.size,
#    4388         get_next_color_func=self._get_patches_for_fill.get_next_color)
#    4390 if plotnonfinite and colors is None:
#    4391     c = np.ma.masked_invalid(c)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axes/_axes.py:4229, in Axes._parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4226             raise invalid_shape_exception(c.size, xsize) from err
#    4227         # Both the mapping *and* the RGBA conversion failed: pretty
#    4228         # severe failure => one may appreciate a verbose feedback.
# -> 4229         raise ValueError(
#    4230             f"'c' argument must be a color, a sequence of colors, "
#    4231             f"or a sequence of numbers, not {c}") from err
#    4232 else:
#    4233     if len(colors) not in (0, 1, xsize):
#    4234         # NB: remember that a single color is also acceptable.
#    4235         # Besides *colors* will be an empty array if c == 'none'.
#
# ValueError: 'c' argument must be a color, a sequence of colors, or a sequence of numbers, not ['pmax[6]' '3.0773376464843523' '5.424356079101585' ...
#  '6.381777954101608' '14.606869506835892' '4.348272705078102']

# %%
plt.scatter(x, y, c=tmax, cmap="viridis", s=2)
cbar = plt.colorbar()
cbar.set_label("Tmax")
plt.show()

# %%
print(max(tmax))
# Out:
# 217.1582458496094

# %%
coordinates = TRAINING_DATA_with_header[:,0:2]

error_sensors = (0,7, 12, 15, 16, 17)
correct_sensors = (1, 2, 3, 4, 5, 6, 8, 9, 10, 11, 13, 14)
start = 2
num_colums = 5
for correct_sensor in correct_sensors:
    start = 2 + (correct_sensor)*5
    coordinates = np.concatenate((coordinates, TRAINING_DATA_with_header[:,start:start+5]), axis=1)

# %%
print(coordinates[0:10,:])
print(coordinates.shape)
# Out:
# [['x' 'y' 'pmax[1]' 'negpmax[1]' 'area[1]' 'tmax[1]' 'rms[1]' 'pmax[2]'
#   'negpmax[2]' 'area[2]' 'tmax[2]' 'rms[2]' 'pmax[3]' 'negpmax[3]'
#   'area[3]' 'tmax[3]' 'rms[3]' 'pmax[4]' 'negpmax[4]' 'area[4]' 'tmax[4]'
#   'rms[4]' 'pmax[5]' 'negpmax[5]' 'area[5]' 'tmax[5]' 'rms[5]' 'pmax[6]'
#   'negpmax[6]' 'area[6]' 'tmax[6]' 'rms[6]' 'pmax[8]' 'negpmax[8]'
#   'area[8]' 'tmax[8]' 'rms[8]' 'pmax[9]' 'negpmax[9]' 'area[9]' 'tmax[9]'
#   'rms[9]' 'pmax[10]' 'negpmax[10]' 'area[10]' 'tmax[10]' 'rms[10]'
#   'pmax[11]' 'negpmax[11]' 'area[11]' 'tmax[11]' 'rms[11]' 'pmax[13]'
#   'negpmax[13]' 'area[13]' 'tmax[13]' 'rms[13]' 'pmax[14]' 'negpmax[14]'
#   'area[14]' 'tmax[14]' 'rms[14]']
#  ['200.0' '200.0' '5.40916137695308' '-17.72120971679692'
#   '4.538778076171775' '22.6' '1.563902099844264' '6.084506225585983'
#   '-19.892542997705423' '3.13232788085943' '72.2' '1.4568649890623775'
#   '3.8113281250000455' '-23.747293403037123' '3.621972656250091' '15.2'
#   '1.531228158342523' '4.89302749260208' '-18.00897216796875'
#   '7.2152587890625' '70.59416047218754' '0.9380417258006218'
#   '9.322305297851583' '-19.47710071556087' '5.520791015625036' '72.4'
#   '1.4128772008397623' '3.0773376464843523' '-19.239129638671898'
#   '2.079597167968722' '28.4' '1.2423609919671548' '26.58125305175781'
#   '-15.62553873396948' '13.374258422851565' '72.2' '1.2114600303010674'
#   '99.36126403808588' '-56.82800598144536' '48.42256713867182' '72.0'
#   '0.971254379792162' '42.06839294433598' '-19.716336059570267'
#   '23.15281921386727' '72.0' '1.2854251254890747' '12.43845825195308'
#   '-18.14815063476567' '7.611375732421812' '72.2' '0.9041567568434608'
#   '7.4548767089843295' '-16.86116333007817' '4.191909179687445'
#   '72.60000000000001' '1.1849430908291505' '6.61187744140625'
#   '-17.68579929404932' '4.88468017578125' '162.8' '1.2849694388717616']
#  ['200.0' '200.0' '4.414289041996498' '-4.736826917729907'
#   '3.720434570312501' '111.8750583489974' '1.2280576103833762'
#   '4.507257080078148' '-3.7871746987557167' '3.267460937500028' '55.0'
#   '1.7090018697551628' '3.94036865234375' '-5.427001953125'
#   '3.4446777343750004' '200.2' '1.172497343590814' '5.549379355338215'
#   '-4.670675659179665' '6.666402587890707' '156.59853476552533'
#   '1.1097676809995796' '9.373913574218705' '-3.8967773437500455'
#   '6.821667480468659' '71.0' '1.489011298567242' '5.424356079101585'
#   '-4.675985717773415' '5.481519775390689' '70.60000000000001'
#   '1.684810954420445' '27.79701538085942' '-11.74290161132808'
#   '14.33465698242194' '71.0' '1.2488689028901845' '96.06256103515624'
#   '-58.80343627929688' '47.55985717773438' '70.8' '1.64660620306549'
#   '38.69020996093752' '-19.613623046874977' '20.574321289062528' '70.8'
#   '1.2364103283001973' '12.326211547851583' '-5.670919799804665'
#   '8.025535888671902' '119.6' '1.201038771484733' '18.47251440324015'
#   '-3.37232360839846' '16.620582275390507' '119.81251175551029'
#   '1.5780089959238763' '13.802252197265602' '-5.154840087890648'
#   '8.758869628906224' '120.0' '1.0939534614387516']
#  ['200.0' '200.0' '4.56719055175779' '-5.985437212886572'
#   '3.490490112304656' '107.8' '1.0154077609855985' '5.3841552734375'
#   '-3.9488525390625' '2.9291503906250003' '28.0' '1.373335827583756'
#   '4.903411865234375' '-4.559234619140625' '1.2236999511718751' '204.6'
#   '1.5086281265918315' '3.795407104492142' '-4.761538696289108'
#   '1.397493286132749' '71.8' '1.1214825410397733' '7.49989624023442'
#   '-5.3434265136718295' '7.260222167968823' '71.8' '1.547935682965207'
#   '5.846232889146142' '-5.021163537272869' '6.073776855468828'
#   '71.54185885456003' '1.5299809782446512' '23.163650512695312'
#   '-11.581954956054688' '11.901321411132812' '71.8' '1.712700336816848'
#   '93.76739807128912' '-62.80132751464839' '46.12118896484381'
#   '71.60000000000001' '1.5094985479524603' '40.33706665039063'
#   '-23.637969970703125' '19.45694580078125' '71.60000000000001'
#   '1.9738034839911447' '9.253250122070312' '-4.282882690429688'
#   '4.517315673828125' '71.8' '1.9953938147125363' '7.336667927701186'
#   '-5.7423828124999545' '11.792258300781397' '71.90821166832471'
#   '1.3330363744393576' '5.9400393489469945' '-3.860549926757813'
#   '5.340139770507813' '6.614830102744022' '1.1839509223438012']
#  ['200.0' '200.0' '5.019058227539063' '-4.229949451611007'
#   '6.786199951171875' '175.60000000000002' '1.3506202085033288'
#   '4.16559753417971' '-5.57604064941404' '1.5443695068359604' '14.0'
#   '1.1150780939534677' '3.791671752929688' '-4.981216430664063'
#   '2.98568115234375' '104.0' '1.374107715035817' '4.848719435606007'
#   '-3.985501098632767' '5.18415039062511' '197.7259321586998'
#   '1.8490993940164515' '10.42225952148442' '-4.9167907714843295'
#   '5.480527343750055' '72.4' '0.8095495525270621' '5.157927493022406'
#   '-3.5946746826172102' '9.393184814453026' '72.08151318899249'
#   '1.6331618996406518' '26.59289855957036' '-10.409298706054642'
#   '12.231570434570358' '72.2' '0.8251312873143367' '89.62043762207031'
#   '-62.65849304199219' '48.82190551757813' '72.0' '1.945644021115404'
#   '37.796774291992165' '-21.11472473144533' '20.897897338867168' '72.0'
#   '1.2245257074158056' '10.900875854492142' '-5.595095825195358'
#   '5.927389526367143' '72.2' '1.491609704220944' '8.450671386718795'
#   '-6.342114257812455' '4.496740722656296' '72.60000000000001'
#   '1.945065357756091' '6.434909613053612' '-5.576315307617165'
#   '15.78963806152358' '72.19542032594195' '1.7389977325770432']
#  ['200.0' '200.0' '3.2502624511719205' '-5.7835865143972205'
#   '2.449455566406323' '159.8' '0.7595146112918868' '4.73602294921875'
#   '-5.137939453125' '4.21104736328125' '71.2' '1.237267690706103'
#   '5.123048368358346' '-4.447103881835915' '4.377708129882854'
#   '71.35723693515054' '1.4175047857943135' '3.0267089843749773'
#   '-6.137963867187523' '1.4235937499999638' '2.6' '1.4748964783539829'
#   '12.557805560052998' '-4.582629394531296' '9.222846679687429'
#   '71.16020108673611' '1.814520329317962' '6.115045900929124'
#   '-4.1721679687500455' '4.2185937499999' '70.75968207746548'
#   '1.7941085704387614' '25.26170959472654' '-10.29804382324221'
#   '11.94975891113279' '71.2' '1.627492637214193' '106.10942993164063'
#   '-68.65347900390623' '49.84617065429691' '71.0' '1.4717705004896646'
#   '42.20202331542964' '-20.666323852539108' '21.79563842773432' '71.0'
#   '1.6044951889273535' '13.956658935546898' '-5.728704833984352'
#   '7.386076660156277' '71.0' '1.3188732102230063' '8.721951610510914'
#   '-4.3964355468749545' '9.127136230468889' '71.41153540079259'
#   '1.5139879678779726' '4.48308013353919' '-5.361822509765602'
#   '3.366541748046916' '160.18570451065145' '1.3236212632805544']
#  ['200.0' '200.0' '3.724728393554642' '-3.405553318529474'
#   '2.957783813476499' '199.6' '1.4490231521400236' '4.1225097656249545'
#   '-5.2047607421875455' '2.6245898437499364' '135.8' '1.4934966264745455'
#   '5.695571283002394' '-4.469137573242165' '6.98291076660164'
#   '4.406039489677118' '1.6964550903663007' '3.8623291015625214'
#   '-5.890675712828418' '1.4822753906250228' '15.8' '1.2967497553154066'
#   '8.969863891601562' '-4.753568366494605' '5.281024169921875' '71.2'
#   '1.1242394518776968' '5.71607360839846' '-4.395550511897532'
#   '2.2912200927734605' '128.6' '1.074482857970006' '23.36698608398433'
#   '-12.84236450195317' '12.652919921874949' '71.0' '1.307817380407814'
#   '101.39801635742184' '-56.38222656250002' '45.46407592773435' '71.0'
#   '1.1458769962560351' '43.24384460449221' '-19.25469055175779'
#   '20.281602783203155' '71.0' '2.2186386204919786' '9.516567993164015'
#   '-6.212802124023483' '4.930428466796821' '71.0' '0.8714463810598039'
#   '7.63942260742192' '-5.053392997257609' '5.209758300781323' '71.4'
#   '1.3514404445865615' '3.760919189453148' '-5.605902099609352'
#   '1.9667626953125368' '102.0' '1.2585813127319936']
#  ['200.0' '200.0' '4.5160064697265625' '-4.608078002929688'
#   '3.4670532226562503' '6.6000000000000005' '1.6825534376614515'
#   '5.4449615478515625' '-4.9640960693359375' '4.050228881835937' '181.0'
#   '1.1265900013424914' '4.4693756103515625' '-4.3652191162109375'
#   '2.882394409179688' '178.0' '1.6926080156441912' '4.2277773030907895'
#   '-5.080001831054688' '7.000576782226563' '200.76192217002125'
#   '1.88454521025642' '12.389180403985687' '-5.5624847412109375'
#   '8.498645019531251' '71.90264361431569' '0.8217867625473623'
#   '6.625668334960892' '-3.567568969726608' '5.94287536621082' '165.4'
#   '1.8235657577462792' '28.29235534667964' '-10.002444458007858'
#   '17.298611450195178' '72.0' '2.100437167504486' '102.6088470458984'
#   '-64.91477355957034' '49.537380981445295' '71.8' '1.2090629493981404'
#   '41.71147155761719' '-24.768630981445312' '21.998123168945312' '71.8'
#   '1.31412012434763' '10.503292846679642' '-5.223541128449853'
#   '5.622017822265571' '72.0' '0.7143986445707781' '7.822296142578125'
#   '-4.367889404296875' '4.75745849609375' '72.4' '1.3686656496025174'
#   '4.45130310058596' '-5.10240783691404' '1.9657562255859604' '195.4'
#   '1.4810890459981143']
#  ['200.0' '200.0' '3.498582414471746' '-6.120251234879227'
#   '4.314651489257949' '152.0924870667975' '2.07093471529098'
#   '4.786600113939054' '-4.2509887695312045' '5.09346435546886'
#   '80.48890668694958' '0.9567066723573476' '5.109399414062523'
#   '-4.964636230468727' '2.771093750000023' '141.0' '1.81824158374069'
#   '3.727236938476608' '-6.876217651367142' '2.28297485351568'
#   '23.200000000000003' '0.8329320775840686' '10.170211791992188'
#   '-3.756362915039064' '10.880706787109377' '72.2' '1.2054913903239235'
#   '5.895797729492188' '-4.4769439697265625' '5.67491455078125' '118.0'
#   '1.2664389499104018' '28.544223022460983' '-13.742092895507769'
#   '13.85653442382818' '72.2' '1.967920752988634' '99.8020538330078'
#   '-65.87363586425784' '46.85283935546872' '72.2' '1.5301441907649735'
#   '40.901083374023415' '-21.22507629394533' '23.059157714843696' '72.2'
#   '1.6784804837060705' '9.434542846679731' '-5.077420043945267'
#   '7.446968994140753' '72.2' '1.490622070606895' '9.386575317382835'
#   '-4.979574584960915' '5.494472656250037' '72.60000000000001'
#   '1.4520399283040026' '5.31275329589846' '-4.24486389160154'
#   '3.4215460205078445' '184.6' '1.3254469221919645']
#  ['200.0' '200.0' '5.1213117984452' '-3.360784441633519'
#   '10.358022460937718' '196.0195528877468' '0.7296153834185726'
#   '4.624288940429665' '-5.028359985351585' '2.611655273437464' '71.8'
#   '1.3522657201210069' '4.416955566406273' '-4.860266113281227'
#   '2.489750976562528' '131.8' '1.1431940575996538' '3.877835083007767'
#   '-5.0935035620742495' '1.8683801269530704' '186.0' '1.208121905489853'
#   '6.997683715820358' '-5.627499389648392' '3.81986450195318' '71.8'
#   '2.1870771478330906' '3.784637451171875' '-6.237152099609375'
#   '1.7969543457031252' '147.0' '0.8648681434949012' '24.30645751953125'
#   '-11.97052001953125' '11.6976806640625' '71.60000000000001'
#   '1.349982189600735' '103.0309997558594' '-67.9121154785156'
#   '50.43676879882817' '71.60000000000001' '1.5521205779235012'
#   '42.62644958496094' '-21.286941528320312' '22.971868896484377'
#   '71.60000000000001' '1.4746956154413218' '7.1108520507812045'
#   '-5.052600097656296' '2.7906005859374545' '71.60000000000001'
#   '1.7982555806338745' '10.73685913085933' '-5.558360174672481'
#   '6.030239257812446' '72.0' '1.029652517810579' '5.130885027718201'
#   '-4.701235961914108' '4.504266967773356' '188.7918933863141'
#   '1.92317400403762']]
# (385501, 62)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import helpers.processing_helpers as ph

from sklearn.model_selection import RandomizedSearchCV

from sklearn.ensemble import RandomForestRegressor

from sklearn.metrics import make_scorer

# %%
df_dev = pd.read_csv("./dataset/development.csv")

# %%
y = df_dev[['x', 'y']].copy()
X = df_dev.drop(columns=['x', 'y'])

# %%
noise_indexes = [0,7,12,15,16,17]
acc_idxs = [1,2,3,4,5,6,8,9,10,11,13,14]
features = ["pmax", "negpmax", 'area', 'tmax', 'rms']

negpmax = X[ph.get_column_names(['negpmax'], acc_idxs)]

# %%
negpmax_coor = pd.concat([negpmax, y], axis=1)

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)
 
# All dataframes hereafter reflect these changes.
df = negpmax_coor.loc[(negpmax_coor['x'] == 200) & (negpmax_coor['y'] == 375)]

display(df)
#380229

pd.reset_option('all')
# Out:
#       negpmax[1]  negpmax[2]  negpmax[3]  negpmax[4]  negpmax[5]  negpmax[6]  \
# 2400  -16.845502  -19.353058  -16.584024  -21.003699  -18.581574  -18.464734
# 2401   -4.772333   -3.356433   -4.445096   -3.235568  -16.051645   -6.261942
# 2402   -4.598397   -4.461237   -5.083130   -3.961035  -12.540610   -6.524408
# 2403   -4.573129   -7.157520   -6.395660   -3.485284  -15.651889   -8.180017
# 2404   -4.400827   -4.042838   -4.852478   -4.794528  -13.190500   -7.997955
# 2405   -4.039056   -4.828913   -4.184933   -5.103401  -14.017719   -7.456686
# 2406   -2.950713   -3.071844   -4.540878   -3.895114  -18.272247  -10.899057
# 2407   -4.874506   -3.699374   -5.355781   -3.833533  -13.254285   -8.363217
# 2408   -5.621796   -5.616653   -3.516595   -3.387428  -15.807306   -6.815039
# 2409   -4.182402   -3.644855   -4.836679   -4.740689  -17.318515  -10.277640
# 2410   -4.589063   -3.324811   -4.477774   -5.064734  -13.593661  -10.801437
# ...

# %%
display(negpmax_coor)
# Out:
#         negpmax[1]  negpmax[2]  negpmax[3]  negpmax[4]  negpmax[5]  \
# 0       -17.721210  -19.892543  -23.747293  -18.008972  -19.477101
# 1        -4.736827   -3.787175   -5.427002   -4.670676   -3.896777
# 2        -5.985437   -3.948853   -4.559235   -4.761539   -5.343427
# 3        -4.229949   -5.576041   -4.981216   -3.985501   -4.916791
# 4        -5.783587   -5.137939   -4.447104   -6.137964   -4.582629
# ...            ...         ...         ...         ...         ...
# 385495  -26.266623  -29.947864  -36.910852   -3.202997   -5.162094
# 385496  -26.138474  -34.662131  -37.721255   -5.173907   -5.582098
# 385497  -30.943115  -35.670273  -38.344370   -5.173453   -4.633670
# 385498  -22.520367  -33.298181  -36.103391   -4.629693   -4.630464
# 385499  -26.616895  -31.891431  -37.448969  -17.717380  -18.863248
#
#         negpmax[6]  negpmax[8]  negpmax[9]  negpmax[10]  negpmax[11]  \
# 0       -19.239130  -15.625539  -56.828006   -19.716336   -18.148151
# ...
